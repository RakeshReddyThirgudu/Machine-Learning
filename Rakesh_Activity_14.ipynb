# %% [markdown]
# # Topic Modeling using BERT
# In this activity we will use BERTopic, which is a topic modeling technique that leverages BERT embeddings and a class-based TF-IDF to create dense clusters allowing for easily interpretable topics whilst keeping important words in the topic descriptions.
#
# For more details on BERTopic, see:
# https://maartengr.github.io/BERTopic/index.html
#
# https://github.com/MaartenGr/BERTopic

# %% [markdown]
# You can compare the resulting topics from this activity with topics we derived in our earlier activity using LDA for topic modeling.

# %%
#run once!
# !pip install bertopic
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.13.1)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 58.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.34)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.1+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.25.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 57.9 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3580425 sha256=527edcb5d0ccbb801e8adb865fe1e092829ffd4f0409210777e31d81bca943b8
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=ee05d9f87c59f6633b92901464e0394700c21724ae6ad48b055e0f58af6f67a8
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=3d70416c3c1f6729c7004e4daab946a0f6145ffbe02179b5930fde68d31f55e7
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55509 sha256=bd71a246df456d04c6d5882b19ce601962f494ffdaa78f4baab56f7210f4569a
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.13.4 pynndescent-0.5.8 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.27.4 umap-learn-0.5.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bertopic[visualization] in /usr/local/lib/python3.9/dist-packages (0.14.1)
# WARNING: bertopic 0.14.1 does not provide the extra 'visualization'
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (0.8.29)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.2.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (2.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (4.65.0)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.5.3)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (0.5.3)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.22.4)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (5.13.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.10.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (0.29.34)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.1.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.13.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.8.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.27.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.1.98)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.15.1+cu118)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.5.8)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.11.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (67.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic[visualization]) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.3.0)

# %% [markdown]
# ## Data & Scenario
#
# We will use the same dataset on restaurant reviews we used for the earlier activity using LDA for topic modeling so that you can compare the results.
#
# As explained earlier, we can explore whether there are certain topics that people write about in their reviews. These topics can be used to come up with different strategies to engage users on online platforms or other channels.
#
# This is a small dataset for learning purposes and to avoid long processing times.
# You can use any other textual data as input. Depending on the data format, you may have to use different functions to import your text data. Once you have your data imported as a dataframe, where one colum contains the *documents*, the rest will be the same.
#
# Download the file "**Restaurant_Reviews.tsv**" form elearn and upload it to your session before processing.

# %%
# importing restaurant reviews dataset
import pandas as pd
df=pd.read_csv('Restaurant_Reviews.tsv',delimiter="\t")
df.head(2)
# Out:
#                      Review  Sentiment
# 0  Wow... Loved this place.          1
# 1        Crust is not good.          0

# %% [markdown]
# The sentiment for each review has been manually labeled for this dataset, we will not be using it for this activity; we only use the Review content.
#
# There are 996 unique reviews (documents, in NLP terminology).

# %%
len(df)
docs=df['Review']
docs=docs.drop_duplicates() #drop duplicate reviews
docs=docs.values
len(docs)
# Out:
# 996

# %%
#let's take a look at a document
docs[2]
# Out:
# 'Not tasty and the texture was just nasty.'

# %% [markdown]
# ## Pre-processing
# Here we won't need to use the pre-processing steps as we did in our earlier activity, since the library we are using is going to automatically apply the needed text pre-processing.

# %% [markdown]
# ## Importing BERTopic

# %%
#import BERTTopic
from bertopic import BERTopic

# %% [markdown]
# This package is very easy to use, but there are several steps happening in the background (which are customizable, btw) and utilizes advanced pre-trained models (more on this later).

# %% [markdown]
# ## Embeddings
# Let's recall our previous activities when we used RNNs for sentiment analysis and document classification.
# Remember those RNN models had an embedding layer (the first layer) that would convert tokens (words represented as integers) to vectors (word vectors); in sum, it would create word embeddings (vectors) from tokens so that similar words would be close in the resulting vector-space.
#
# Here, we have a similar process at the sentence-level (instead of token-level). The first step (happens in the background) is to create sentence embeddings using pre-trained models using what is known as "sentence-transformers"; sentence-transformers convert sentences into vector representations. These models are usually trained on very large collections of text (some for multilple languages) where the training goal is for the model to be able to predict some missing part of text (e.g., at the word or sentence level). This process can also be done at the document level, i.e., document embeddings.
#
# Here is a repository for pre-trained models https://huggingface.co/models. Depending on what sort of textual data you are working with (e.g., scientific articles, social media, etc.), you might want to use a library that is trained on type of text that is similar in nature to what you have.
#
# We will be using the default "distilbert-base-nli-mean-tokens" model (link to original paper https://arxiv.org/abs/1910.01108 ) for the english language.

# %%
# creating a instance of bertopic for "english", we are setting the parameters to save topic probablities (will use them later for visualization)
model = BERTopic(language="english",calculate_probabilities=True,verbose=True)

# %% [markdown]
# Notice that we are not specifying the number of topics here, contrary to when we do topic modeling using LDA.
#
# You could think of this as sth similar to what we had when we used DBSCAN for clustering where we don't specifiy number of clusters (vs. k-means where we had to specify the number of clusters).

# %% [markdown]
# ## Running BERTopic on our corpus

# %%
# apply the model on our documents and save both topics and probabilities (probability of each document belonging to any of the topics)
topics, probabilities = model.fit_transform(docs)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# 2023-04-13 08:21:01,495 - BERTopic - Transformed documents to Embeddings
# 2023-04-13 08:21:14,050 - BERTopic - Reduced dimensionality
# 2023-04-13 08:21:14,164 - BERTopic - Clustered reduced embeddings

# %% [markdown]
# ## Derived Topics and their frequency
#
# Topic **-1** refers to all documents that did not have any topics assigned (outlier topic).

# %%
# number of topics and freq (number of documents assigned to each topic)
model.get_topic_freq().shape
# Out:
# (25, 2)

# %%
# Topic -1 refers to all documents that did not have any topics assigned (outlier topic).
model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1    335
# 1       0     61
# 2       1     56
# 3       2     53
# 4       3     47
# 5       4     43
# 6       5     43
# 7       6     42
# 8       7     39
# 9       8     32
# 10      9     32
# 11     10     20
# 12     11     19
# 13     12     18
# 14     13     17
# 15     14     17
# 16     15     16
# 17     16     16
# 18     17     15
# 19     18     14
# 20     19     13
# 21     20     13
# 22     21     13
# 23     22     12
# 24     23     10

# %% [markdown]
# ### Question 1
# How many topics were derived (aside from the outlier cluster)?
#
# Answer: 24 topics.

# %% [markdown]
# ###Question 2
# How many documents are assigned to the first and second topic?
#
# Answer: 56 documents to topic 1.
# 53 documents to topic 2.

# %% [markdown]
# ## Top words for a topic
# Let's take a look at top words that represent the first topic (topic=1), which has the most documents. You can simply change the topic number to look at the top words for other topics.

# %%
# get top words for first topic
model.get_topic(1)
# Out:
# [('experience', 0.08575303234845513),
#  ('disappointed', 0.058081079622886514),
#  ('was', 0.05694773405343657),
#  ('it', 0.052638412876519575),
#  ('good', 0.04150761584285264),
#  ('very', 0.040579582117416794),
#  ('you', 0.03835505836922988),
#  ('ambiance', 0.038079280180839954),
#  ('not', 0.03772586668890369),
#  ('overall', 0.036857514510977525)]

# %% [markdown]
# ## Visualizing topics
# We can also visualize the derived topics (note that we installed the visualiazation library in the beginning of this notebook).

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="16d43566-ad0a-4e17-9983-3c3592c67966" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16d43566-ad0a-4e17-9983-3c3592c67966")) {                    Plotly.newPlot(                        "16d43566-ad0a-4e17-9983-3c3592c67966",                        [{"customdata":[[0,"back | go | will | be | wont",61],[1,"experience | disappointed | was | it | good",56],[2,"place | this | to | recommend | town",53],[3,"minutes | waited | we | for | took",47],[4,"service | slow | was | quick | the",43],[5,"were | fries | potato | hot | the",43],[6,"flavor | spicy | and | bland | was",42],[7,"food | service | good | great | atmosphere",39],[8,"food | was | did | lunch | the",32],[9,"vegas | buffet | in | breakfast | for",32],[10,"stars | give | zero | deserves | star",20],[11,"waiter | waitress | friendly | was | our",19],[12,"staff | friendly | are | always | the",18],[13,"price | overpriced | prices | is | considering",17],[14,"restaurant | cafe | an | restaurants | is",17],[15,"eat | here | eating | again | there",16],[16,"fish | seafood | shrimp | fresh | crab",16],[17,"order | their | they | them | can",15],[18,"management | rude | talk | disrespected | treated",14],[19,"sushi | this | quality | is | place",13],[20,"steak | steaks | best | three | plate",13],[21,"server | our | he | attentive | very",13],[22,"pizza | pizzas | homemade | good | area",12],[23,"shower | bathrooms | decor | bathroom | dirty",10]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[61,56,53,47,43,43,42,39,32,32,20,19,18,17,17,16,16,15,14,13,13,13,12,10],"sizemode":"area","sizeref":0.038125,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[13.739535331726074,7.074812412261963,11.90799617767334,11.319719314575195,-6.603368759155273,6.772436141967773,1.3637194633483887,14.690564155578613,12.228522300720215,11.83488941192627,11.75344181060791,-6.389272689819336,-6.039516925811768,14.238731384277344,8.523868560791016,13.656036376953125,2.0373589992523193,1.7821897268295288,-6.131202220916748,11.5972261428833,2.2747673988342285,-6.281978607177734,1.5522536039352417,8.390950202941895],"xaxis":"x","y":[-1.5812455415725708,-8.76634693145752,-2.671844482421875,-2.22817063331604,7.676870346069336,-9.079656600952148,3.2856996059417725,-1.8267263174057007,-1.977518081665039,-2.1627087593078613,-1.9110901355743408,8.03471851348877,8.68331241607666,-1.8555773496627808,-7.234294414520264,-1.903925895690918,3.96150803565979,3.7048816680908203,9.096685409545898,-2.6133222579956055,4.2000555992126465,8.545098304748535,3.474311351776123,-7.378814220428467],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar": ...

# %% [markdown]
# ## Document-Topic probablities
#
# Each document in our corpus has a probability for belonging to each of the derived topics; we can derive these probabilities to use them for some other task (for example, as features for some predictive modeling task).

# %%
probabilities.shape
# Out:
# (996, 24)

# %%
# for example, we can export all these document-topic probabilities as a csv file.
# pd.DataFrame(probabilities).to_csv("probs.csv")

# %% [markdown]
# ## Visualize Topic probability distribution
# We can also visualize the Topic probability distribution for a specific document.
# Note that topics with a probablity beloew the specified threshold are not shown.

# %%
docs[10] # review number 5
# Out:
# 'Service was very prompt.'

# %%
# probablity of doc[4] (review 5) belonging to each of the topics
model.visualize_distribution(probabilities[10],min_probability=0.005)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5f15e50f-db4d-401d-b67a-b3ff5072f96e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f15e50f-db4d-401d-b67a-b3ff5072f96e")) {                    Plotly.newPlot(                        "5f15e50f-db4d-401d-b67a-b3ff5072f96e",                        [{"marker":{"color":"#C8D2D7","line":{"color":"#6E8484","width":1}},"orientation":"h","x":[0.016846644653909944,0.030230143425857288,0.020595596728134782,0.027363517560320523,0.28362071708575604,0.018112343242426485,0.016497761395847802,0.04148700269218424,0.023955201336564508,0.018161603366266345,0.015150461816657624,0.03801684714110657,0.03822138507762611,0.03228167868778576,0.025489927024642305,0.022128018124887044,0.01564514448387101,0.02200973939569008,0.03890259468251187,0.011884299629469122,0.018199128402340555,0.1071035484803589,0.015701108478121183,0.025016248495510415],"y":["<b>Topic 0</b>: back_go_will_be_wont","<b>Topic 1</b>: experience_disappointed_...","<b>Topic 2</b>: place_this_to_recommend_...","<b>Topic 3</b>: minutes_waited_we_for_to...","<b>Topic 4</b>: service_slow_was_quick_t...","<b>Topic 5</b>: were_fries_potato_hot_th...","<b>Topic 6</b>: flavor_spicy_and_bland_w...","<b>Topic 7</b>: food_service_good_great_...","<b>Topic 8</b>: food_was_did_lunch_the","<b>Topic 9</b>: vegas_buffet_in_breakfas...","<b>Topic 10</b>: stars_give_zero_deserve...","<b>Topic 11</b>: waiter_waitress_friendl...","<b>Topic 12</b>: staff_friendly_are_alwa...","<b>Topic 13</b>: price_overpriced_prices...","<b>Topic 14</b>: restaurant_cafe_an_rest...","<b>Topic 15</b>: eat_here_eating_again_t...","<b>Topic 16</b>: fish_seafood_shrimp_fre...","<b>Topic 17</b>: order_their_they_them_c...","<b>Topic 18</b>: management_rude_talk_di...","<b>Topic 19</b>: sushi_this_quality_is_p...","<b>Topic 20</b>: steak_steaks_best_three...","<b>Topic 21</b>: server_our_he_attentive...","<b>Topic 22</b>: pizza_pizzas_homemade_g...","<b>Topic 23</b>: shower_bathrooms_decor_..."],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar ...

# %% [markdown]
# ### Question 3
# Which topic does the 10th review belong to?
#
# Answer: Topic 4.

# %% [markdown]
# ## What topic would a new review be most similar to?
# Let's see which topic(s) a new review would be more similar to.
#
# We have the option to derive similarity of a new piece of text to the derived topcis (in terms of cosine similarity between embeddings).

# %%
new_review="The food was too salty but I liked the atmosphere."

# %%
model.find_topics(new_review)
# Out:
# ([8, 6, 16, 19, 20],
#  [0.32735023533094737,
#   0.3121043308709059,
#   0.3071931635621252,
#   0.270192204328968,
#   0.2601766192034405])

# %% [markdown]
# ###Question 4
# Which topic(s) is the new review most simlar to?
#
# Answer: Topics 8, 6, 16, 19, 20.

# %%
model.get_topic(15)
# Out:
# [('eat', 0.09061098662097605),
#  ('here', 0.07391281197873827),
#  ('eating', 0.07128795475715385),
#  ('again', 0.06732536520354557),
#  ('there', 0.059133167922716896),
#  ('enjoyed', 0.05138186753251858),
#  ('each', 0.04928983477945591),
#  ('twice', 0.04928983477945591),
#  ('would', 0.04855981969345222),
#  ('be', 0.04594797935360452)]
